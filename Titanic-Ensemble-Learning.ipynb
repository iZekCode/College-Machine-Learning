# %% [markdown]
# Nama: Filbert Naldo Wijaya
#
# NIM: 2702235696

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read data

train_df = pd.read_csv('titanic_train.csv')
test_df = pd.read_csv('titanic_test.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Descriptive analysis of age

train_df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# Insight: Rata-rata usia penumpang kapal Titanic adalah 29.7 tahun, dengan range dari 0.42 sampai 80 tahun.

# %%
# calculate the survival count and percentage by gender using cross tabulation

survive_by_gender = train_df.groupby(["Sex", "Survived"]).size().reset_index(name="Count")

gender_count = train_df["Sex"].value_counts()

survival_percentage = survive_by_gender[survive_by_gender["Survived"] == 1].set_index("Sex")["Count"] / gender_count * 100
survival_percentage = survival_percentage.map(lambda x: f"{round(x, 3)} %")

print("Survival Count by Gender:\n", survive_by_gender)
print("\nSurvival Rate by Gender:\n", survival_percentage)
# Out:
# Survival Count by Gender:
#        Sex  Survived  Count
# 0  female         0     81
# 1  female         1    233
# 2    male         0    468
# 3    male         1    109
#
# Survival Rate by Gender:
#  Sex
# female    74.204 %
# male      18.891 %
# dtype: object

# %% [markdown]
# Insight:
# Penumpang dengan gender perempuan mempunyai persentase survive lebih tinggi yaitu sebesar 74.204 %, daripada laki-laki yaitu hanya sebesar 18.891 %.

# %%
# Scatterplot to see is there any correlation between age and fare

plt.figure(figsize=(10, 6))
sns.scatterplot(x=train_df["Age"], y=train_df["Fare"], alpha=0.5)
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# Insight:
#
# Mayoritas fare yang dibayar oleh penumpang tergolong rendah.
#
# Terdapat outlier pada fare, di mana terdapat penumpang  membayar fare yang sangat mahal
#
# Berdasarkan scatterplot, tidak ada korelasi/hubungan antara usia dan fare. Fare terdistribusi secara random tanpa memandang usia penumpang.

# %%
# Show the distribution of gender

gender_counts = train_df['Sex'].value_counts()

plt.bar(gender_counts.index, gender_counts.values, color=['red', 'yellow'])
plt.title("Ditribution of Gender")
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Insight: Mayoritas penumpang kapal Titanic adalah laki-laki.

# %%
# Boxplot of fare grouped by passenger class

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x='Pclass', y='Fare', data=train_df)
plt.title("Fare Distribution by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight:
#
# Median fare dari class 1 (First Class) jauh lebih tinggi dari 2 kelas lainnya. Hal ini menunjukkan adanya perbedaan yang jelas dalam ticket pricing.
#
# Class 1 mempunyai IQR yang lumayan besar. Artinya harga tiket di class 1 sangat bervariasi. Berbeda dengan class 2 dan 3 yang IQRnya lumayan kecil, artinya pada class 2 dan 3 variasi harga tiketnya lebih sedikit.
#
# Tiap class mempunyai outlier, artinya ada penumpang yang membayar fare dengan harga di atas standar per class. Class 1 mempunyai outlier yang sangat tinggi/jauh, artinya ada penumpang class 1 yang membayar fare sangat mahal.

# %% [markdown]
# # Data Preprocessing

# %%
# check data train

train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# check data test

test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
# check sum of missing values for each column in train data

train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# check sum of missing values for each column in test data

test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# check if there is duplicate values in train data

train_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# describe data

train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Data Cleaning

# %%
# filling missing values in column 'Age' using median

train_df['Age'] = train_df['Age'].fillna(value=train_df['Age'].median())
test_df['Age'] = test_df['Age'].fillna(value=test_df['Age'].median())

# %%
# filling missing values in column 'Cabin' by filling them with value 'Unknown'

train_df['Cabin'] = train_df['Cabin'].fillna(value="Unknown")
test_df['Cabin'] = test_df['Cabin'].fillna(value="Unknown")

# %%
# filling missing values in column 'Embarked' using mode (modus)

train_df['Embarked'] = train_df['Embarked'].fillna(value=train_df["Embarked"].mode()[0])
test_df['Embarked'] = test_df['Embarked'].fillna(value=test_df["Embarked"].mode()[0])

# %%
# filling missing values in column 'Fare' using mean

test_df['Fare'] = test_df['Fare'].fillna(value=test_df["Fare"].mean())

# %%
train_df.info() # no missing values already
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test_df.info() # no missing values already
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    float64
#  9   Cabin        418 non-null    object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %% [markdown]
# Perform Encoding on Categorical Features

# %%
# encode 'Sex' column
train_df["Sex"] = train_df["Sex"].map({"male": 0, "female": 1})
test_df["Sex"] = test_df["Sex"].map({"male": 0, "female": 1})

# %% [markdown]
# Untuk 'Sex' saya menggunakan Label Encoding, karena 'Sex' hanya punya 2 kategori (binary) yaitu male dan female sehingga bisa encode dengan 2 value yaitu 0 dan 1.

# %%
# encode 'Embarked' column
train_df["Embarked_Q"] = (train_df["Embarked"] == "Q").astype(int)
train_df["Embarked_S"] = (train_df["Embarked"] == "S").astype(int)
train_df.drop(columns=["Embarked"], inplace=True)

test_df["Embarked_Q"] = (test_df["Embarked"] == "Q").astype(int)
test_df["Embarked_S"] = (test_df["Embarked"] == "S").astype(int)
test_df.drop(columns=["Embarked"], inplace=True)

# %% [markdown]
# Untuk 'Embarked' saya menggunakan One-Hot Encoding karena column ini mempunyai 3 unique categorical value yaitu C, Q, dan S di mana 3 value ini tidak ada order/rank tertentu (tidak ada port yang paling bagus/paling buruk).

# %%
train_df # after encoding
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila, Rev. Juozas    0  27.0      0
# 887                       Graham, Miss. Margaret Edith    1  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    1  28.0      1
# 889                              Behr, Mr. Karl Howell    0  26.0      0
# 890                                Dooley, Mr. Patrick    0  32.0      0
#
#      Parch            Ticket     Fare    Cabin  Embarked_Q  Embarked_S
# 0        0         A/5 21171   7.2500  Unknown           0           1
# 1        0          PC 17599  71.2833      C85           0           0
# 2        0  STON/O2. 3101282   7.9250  Unknown           0           1
# 3        0            113803  53.1000     C123           0           1
# 4        0            373450   8.0500  Unknown           0           1
# ..     ...               ...      ...      ...         ...         ...
# 886      0            211536  13.0000  Unknown           0           1
# 887      0            112053  30.0000      B42           0           1
# 888      2        W./C. 6607  23.4500  Unknown           0           1
# 889      0            111369  30.0000     C148           0           0
# 890      0            370376   7.7500  Unknown           1           0
#
# [891 rows x 13 columns]

# %%
test_df # after encoding
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
#       Age  SibSp  Parch              Ticket      Fare    Cabin  Embarked_Q  \
# 0    34.5      0      0              330911    7.8292  Unknown           1
# 1    47.0      1      0              363272    7.0000  Unknown           0
# 2    62.0      0      0              240276    9.6875  Unknown           1
# 3    27.0      0      0              315154    8.6625  Unknown           0
# 4    22.0      1      1             3101298   12.2875  Unknown           0
# ..    ...    ...    ...                 ...       ...      ...         ...
# 413  27.0      0      0           A.5. 3236    8.0500  Unknown           0
# 414  39.0      0      0            PC 17758  108.9000     C105           0
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500  Unknown           0
# 416  27.0      0      0              359309    8.0500  Unknown           0
# 417  27.0      1      1                2668   22.3583  Unknown           0
#
#      Embarked_S
# 0             0
# 1             1
# 2             0
# 3             1
# 4             1
# ..          ...
# 413           1
# 414           0
# 415           1
# 416           1
# 417           0
#
# [418 rows x 12 columns]

# %% [markdown]
# Normalization/Standardization

# %%
# Visualize 'Fare' and 'Age' distribution

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Fare Distribution
sns.histplot(train_df["Fare"], bins=50, kde=True, ax=axes[0])
axes[0].set_title("Fare Distribution")

# Age Distribution
sns.histplot(train_df["Age"], bins=50, kde=True, ax=axes[1])
axes[1].set_title("Age Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# Fare: right skewed distribution dan ada outlier yang sangat jauh/besar, maka terapkan MinMax Normalization
#
# Age: Normal distribution, maka terapkan Z-Score Standardization

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Normalize 'Fare'
scaler_fare = MinMaxScaler()
train_df["Fare"] = scaler_fare.fit_transform(train_df[["Fare"]])
test_df["Fare"] = scaler_fare.fit_transform(test_df[["Fare"]])

# Standardize 'Age'
scaler_age = StandardScaler()
train_df["Age"] = scaler_age.fit_transform(train_df[["Age"]])
test_df["Age"] = scaler_age.fit_transform(test_df[["Age"]])

# %%
train_df # after normalization/standardization
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0 -0.565736      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  0.663861      1
# 2                               Heikkinen, Miss. Laina    1 -0.258337      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  0.433312      1
# 4                             Allen, Mr. William Henry    0  0.433312      0
# ..                                                 ...  ...       ...    ...
# 886                              Montvila, Rev. Juozas    0 -0.181487      0
# 887                       Graham, Miss. Margaret Edith    1 -0.796286      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    1 -0.104637      1
# 889                              Behr, Mr. Karl Howell    0 -0.258337      0
# 890                                Dooley, Mr. Patrick    0  0.202762      0
#
#      Parch            Ticket      Fare    Cabin  Embarked_Q  Embarked_S
# 0        0         A/5 21171  0.014151  Unknown           0           1
# 1        0          PC 17599  0.139136      C85           0           0
# 2        0  STON/O2. 3101282  0.015469  Unknown           0           1
# 3        0            113803  0.103644     C123           0           1
# 4        0            373450  0.015713  Unknown           0           1
# ..     ...               ...       ...      ...         ...         ...
# 886      0            211536  0.025374  Unknown           0           1
# 887      0            112053  0.058556      B42           0           1
# 888      2        W./C. 6607  0.045771  Unknown           0           1
# 889      0            111369  0.058556     C148           0           0
# 890      0            370376  0.015127  Unknown           1           0
#
# [891 rows x 13 columns]

# %%
test_df # after normalization/standardization
# Out:
#      PassengerId  Pclass                                          Name  Sex  \
# 0            892       3                              Kelly, Mr. James    0
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2            894       2                     Myles, Mr. Thomas Francis    0
# 3            895       3                              Wirz, Mr. Albert    0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf    0
# 414         1306       1                  Oliva y Ocana, Dona. Fermina    1
# 415         1307       3                  Saether, Mr. Simon Sivertsen    0
# 416         1308       3                           Ware, Mr. Frederick    0
# 417         1309       3                      Peter, Master. Michael J    0
#
#           Age  SibSp  Parch              Ticket      Fare    Cabin  \
# 0    0.386231      0      0              330911  0.015282  Unknown
# 1    1.371370      1      0              363272  0.013663  Unknown
# 2    2.553537      0      0              240276  0.018909  Unknown
# 3   -0.204852      0      0              315154  0.016908  Unknown
# 4   -0.598908      1      1             3101298  0.023984  Unknown
# ..        ...    ...    ...                 ...       ...      ...
# 413 -0.204852      0      0           A.5. 3236  0.015713  Unknown
# 414  0.740881      0      0            PC 17758  0.212559     C105
# 415  0.701476      0      0  SOTON/O.Q. 3101262  0.014151  Unknown
# 416 -0.204852      0      0              359309  0.015713  Unknown
# 417 -0.204852      1      1                2668  0.043640  Unknown
#
#      Embarked_Q  Embarked_S
# 0             1           0
# 1             0           1
# 2             1           0
# 3             0           1
# 4             0           1
# ..          ...         ...
# 413           0           1
# 414           0           0
# 415           0           1
# 416           0           1
# 417           0           0
#
# [418 rows x 12 columns]

# %% [markdown]
# Data Reduction

# %%
train_df = train_df.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"])
test_df = test_df.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"])

# %%
train_df # final data
# Out:
#      Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked_Q  \
# 0           0       3    0 -0.565736      1      0  0.014151           0
# 1           1       1    1  0.663861      1      0  0.139136           0
# 2           1       3    1 -0.258337      0      0  0.015469           0
# 3           1       1    1  0.433312      1      0  0.103644           0
# 4           0       3    0  0.433312      0      0  0.015713           0
# ..        ...     ...  ...       ...    ...    ...       ...         ...
# 886         0       2    0 -0.181487      0      0  0.025374           0
# 887         1       1    1 -0.796286      0      0  0.058556           0
# 888         0       3    1 -0.104637      1      2  0.045771           0
# 889         1       1    0 -0.258337      0      0  0.058556           0
# 890         0       3    0  0.202762      0      0  0.015127           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ..          ...
# 886           1
# 887           1
# 888           1
# 889           0
# 890           0
#
# [891 rows x 9 columns]

# %%
test_df # final data, but there is no 'Survived' column as Target, so cant be used as test data
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked_Q  Embarked_S
# 0         3    0  0.386231      0      0  0.015282           1           0
# 1         3    1  1.371370      1      0  0.013663           0           1
# 2         2    0  2.553537      0      0  0.018909           1           0
# 3         3    0 -0.204852      0      0  0.016908           0           1
# 4         3    1 -0.598908      1      1  0.023984           0           1
# ..      ...  ...       ...    ...    ...       ...         ...         ...
# 413       3    0 -0.204852      0      0  0.015713           0           1
# 414       1    1  0.740881      0      0  0.212559           0           0
# 415       3    0  0.701476      0      0  0.014151           0           1
# 416       3    0 -0.204852      0      0  0.015713           0           1
# 417       3    0 -0.204852      1      1  0.043640           0           0
#
# [418 rows x 8 columns]

# %% [markdown]
# # Main Models (Decision Tree, Random Forest, AdaBoost, Bagging)

# %% [markdown]
# ## Decision Tree

# %%
# only use train data, split it 70:30

from sklearn.model_selection import train_test_split

X = train_df.drop(columns=["Survived"])
y = train_df["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn import tree

fig = plt.figure(figsize=(25, 10))
_ = tree.plot_tree(model, feature_names=X_train.columns, max_depth=3)

# %%
print(f"Test accuracy: {model.score(X_test, y_test)}")
print(f"Train accuracy: {model.score(X_train, y_train)}")
# Out:
# Test accuracy: 0.7686567164179104
# Train accuracy: 0.9807383627608347

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.81       157
#            1       0.74      0.68      0.71       111
#
#     accuracy                           0.77       268
#    macro avg       0.76      0.76      0.76       268
# weighted avg       0.77      0.77      0.77       268

# %%
from sklearn.metrics import confusion_matrix

df = pd.DataFrame(confusion_matrix(y_test, y_pred),
                  columns = ["Predicted Positive", "Predicted Negative"],
                  index = ["Actual Positive", "Actual Negative"])

df
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive                 131                  26
# Actual Negative                  36                  75

# %% [markdown]
# Sebanyak 131 orang diprediksi survive, dan aslinya memang survive.
#
# Sebanyak 75 orang diprediksi tidak survive, dan aslinya memang tidak survive.
#
# Sebanyak 26 orang diprediksi tidak survive, tetapi aslinya  survive.
#
# Sebanyak 36 orang diprediksi survive, tetapi aslinya tidak survive.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Precision: {precision_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred)}")
print(f"F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.7686567164179104
# Precision: 0.7425742574257426
# Recall: 0.6756756756756757
# F1 Score: 0.7075471698113207

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(model, X, y, cv=10, scoring='accuracy')

print(f"Cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation score: 0.7935705368289638

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_prob = model.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Berdasarkan hasil evaluasi, model dapat dikatakan lumayan baik dalam memprediksi apakah penumpang kapal titanic selamat atau tidak, hal ini bisa dilihat dari kurva ROC di mana kurva condong ke kiri atas.
#
# Score AUC yang dihasilkan yaitu 0.75 dan f1-Score-nya yaitu 70.8%, artinya model dapat memprediksi dengan cukup tepat.
#
# (Karena data tidak balance, maka acuan saya adalah f1-Score)

# %% [markdown]
# ## Random Forest

# %%
# only use train data, split it 70:30

from sklearn.model_selection import train_test_split

X = train_df.drop(columns=["Survived"])
y = train_df["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=10, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(f"Test accuracy: {model.score(X_test, y_test)}")
print(f"Train accuracy: {model.score(X_train, y_train)}")
# Out:
# Test accuracy: 0.7686567164179104
# Train accuracy: 0.971107544141252

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80       157
#            1       0.72      0.71      0.72       111
#
#     accuracy                           0.77       268
#    macro avg       0.76      0.76      0.76       268
# weighted avg       0.77      0.77      0.77       268

# %%
from sklearn.metrics import confusion_matrix

df = pd.DataFrame(confusion_matrix(y_test, y_pred),
                  columns = ["Predicted Positive", "Predicted Negative"],
                  index = ["Actual Positive", "Actual Negative"])

df
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive                 127                  30
# Actual Negative                  32                  79

# %% [markdown]
# Sebanyak 127 orang diprediksi survive, dan aslinya memang survive.
#
# Sebanyak 79 orang diprediksi tidak survive, dan aslinya memang tidak survive.
#
# Sebanyak 30 orang diprediksi tidak survive, tetapi aslinya  survive.
#
# Sebanyak 32 orang diprediksi survive, tetapi aslinya tidak survive.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Precision: {precision_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred)}")
print(f"F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.7686567164179104
# Precision: 0.7247706422018348
# Recall: 0.7117117117117117
# F1 Score: 0.7181818181818181

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(model, X, y, cv=10, scoring='accuracy')

print(f"Cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation score: 0.7980524344569289

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_prob = model.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Berdasarkan hasil evaluasi, model dapat dikatakan lumayan baik dalam memprediksi apakah penumpang kapal titanic selamat atau tidak, hal ini bisa dilihat dari kurva ROC di mana kurva condong ke kiri atas.
#
# Score AUC yang dihasilkan yaitu 0.85 dan f1-Score-nya yaitu 71.8%, artinya model dapat memprediksi dengan cukup tepat.
#
# (Karena data tidak balance, maka acuan saya adalah f1-Score)

# %% [markdown]
# ## AdaBoost

# %%
# only use train data, split it 70:30

from sklearn.model_selection import train_test_split

X = train_df.drop(columns=["Survived"])
y = train_df["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(f"Test accuracy: {model.score(X_test, y_test)}")
print(f"Train accuracy: {model.score(X_train, y_train)}")
# Out:
# Test accuracy: 0.8059701492537313
# Train accuracy: 0.8218298555377207

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       157
#            1       0.79      0.72      0.75       111
#
#     accuracy                           0.81       268
#    macro avg       0.80      0.79      0.80       268
# weighted avg       0.81      0.81      0.80       268

# %%
from sklearn.metrics import confusion_matrix

df = pd.DataFrame(confusion_matrix(y_test, y_pred),
                  columns = ["Predicted Positive", "Predicted Negative"],
                  index = ["Actual Positive", "Actual Negative"])

df
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive                 136                  21
# Actual Negative                  31                  80

# %% [markdown]
# Sebanyak 136 orang diprediksi survive, dan aslinya memang survive.
#
# Sebanyak 80 orang diprediksi tidak survive, dan aslinya memang tidak survive.
#
# Sebanyak 21 orang diprediksi tidak survive, tetapi aslinya  survive.
#
# Sebanyak 31 orang diprediksi survive, tetapi aslinya tidak survive.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Precision: {precision_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred)}")
print(f"F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.8059701492537313
# Precision: 0.7920792079207921
# Recall: 0.7207207207207207
# F1 Score: 0.7547169811320755

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(model, X, y, cv=10, scoring='accuracy')

print(f"Cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation score: 0.8047565543071162

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_prob = model.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Berdasarkan hasil evaluasi, model dapat dikatakan lumayan baik dalam memprediksi apakah penumpang kapal titanic selamat atau tidak, hal ini bisa dilihat dari kurva ROC di mana kurva condong ke kiri atas.
#
# Score AUC yang dihasilkan yaitu 0.86 dan f1-Score-nya yaitu 75.5%, artinya model dapat memprediksi dengan cukup tepat.
#
# (Karena data tidak balance, maka acuan saya adalah f1-Score)

# %% [markdown]
# ## Bagging using Decision Tree

# %%
# only use train data, split it 70:30

from sklearn.model_selection import train_test_split

X = train_df.drop(columns=["Survived"])
y = train_df["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

model = BaggingClassifier(estimator=DecisionTreeClassifier(random_state=42), n_estimators=10, random_state=42).fit(X, y)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(f"Test accuracy: {model.score(X_test, y_test)}")
print(f"Train accuracy: {model.score(X_train, y_train)}")
# Out:
# Test accuracy: 0.7611940298507462
# Train accuracy: 0.9646869983948636

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       157
#            1       0.74      0.66      0.70       111
#
#     accuracy                           0.76       268
#    macro avg       0.76      0.75      0.75       268
# weighted avg       0.76      0.76      0.76       268

# %%
from sklearn.metrics import confusion_matrix

df = pd.DataFrame(confusion_matrix(y_test, y_pred),
                  columns = ["Predicted Positive", "Predicted Negative"],
                  index = ["Actual Positive", "Actual Negative"])

df
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive                 131                  26
# Actual Negative                  38                  73

# %% [markdown]
# Sebanyak 131 orang diprediksi survive, dan aslinya memang survive.
#
# Sebanyak 73 orang diprediksi tidak survive, dan aslinya memang tidak survive.
#
# Sebanyak 26 orang diprediksi tidak survive, tetapi aslinya  survive.
#
# Sebanyak 38 orang diprediksi survive, tetapi aslinya tidak survive.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Precision: {precision_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred)}")
print(f"F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.7611940298507462
# Precision: 0.7373737373737373
# Recall: 0.6576576576576577
# F1 Score: 0.6952380952380952

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(model, X, y, cv=10, scoring='accuracy')

print(f"Cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation score: 0.8159800249687891

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_prob = model.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Berdasarkan hasil evaluasi, model dapat dikatakan lumayan baik dalam memprediksi apakah penumpang kapal titanic selamat atau tidak, hal ini bisa dilihat dari kurva ROC di mana kurva condong ke kiri atas.
#
# Score AUC yang dihasilkan yaitu 0.83 dan f1-Score-nya yaitu 69.5%, artinya model dapat memprediksi dengan cukup tepat.
#
# (Karena data tidak balance, maka acuan saya adalah f1-Score)

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# Berdasarkan 4 model yang sudah dibuat (Decision Tree, Random Forest, AdaBoost, dan Bagging), dapat disimpulkan bahwa model yang terbaik adalah model AdaBoost karena menghasilkan metrics yang nilainya paling tinggi daripada model-model lainnya. Score AUC yang dihasilkan yaitu 0.86 dan f1-Score-nya yaitu 75.5%.
#
# (Karena data tidak balance, maka acuan saya adalah f1-Score)

# %% [markdown]
# # Additional Models (Hyperparemeter Tuning)

# %% [markdown]
# ## Hyperparameter Tuning using Grid Search - Decision Tree

# %%
# only use train data, split it 70:30

from sklearn.model_selection import train_test_split

X = train_df.drop(columns=["Survived"])
y = train_df["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Use grid search to find the best param

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

model = DecisionTreeClassifier(random_state=42)

param_grid = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 5],
    'criterion': ['gini', 'entropy'],
}

grid_search = GridSearchCV(model, param_grid, cv=10, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best accuracy:", grid_search.best_score_)
# Out:
# Best parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 5}
# Best accuracy: 0.8267025089605735

# %%
y_pred = grid_search.best_estimator_.predict(X_test)

# %%
print(f"Test accuracy: {grid_search.best_estimator_.score(X_test, y_test)}")
print(f"Train accuracy: {grid_search.best_estimator_.score(X_train, y_train)}")
# Out:
# Test accuracy: 0.8171641791044776
# Train accuracy: 0.8796147672552167

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       157
#            1       0.82      0.72      0.77       111
#
#     accuracy                           0.82       268
#    macro avg       0.82      0.80      0.81       268
# weighted avg       0.82      0.82      0.82       268

# %%
from sklearn.metrics import confusion_matrix

df = pd.DataFrame(confusion_matrix(y_test, y_pred),
                  columns = ["Predicted Positive", "Predicted Negative"],
                  index = ["Actual Positive", "Actual Negative"])

df
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive                 139                  18
# Actual Negative                  31                  80

# %% [markdown]
# Sebanyak 139 orang diprediksi survive, dan aslinya memang survive.
#
# Sebanyak 80 orang diprediksi tidak survive, dan aslinya memang tidak survive.
#
# Sebanyak 18 orang diprediksi tidak survive, tetapi aslinya  survive.
#
# Sebanyak 31 orang diprediksi survive, tetapi aslinya tidak survive.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Precision: {precision_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred)}")
print(f"F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.8171641791044776
# Precision: 0.8163265306122449
# Recall: 0.7207207207207207
# F1 Score: 0.7655502392344498

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(grid_search.best_estimator_, X, y, cv=10, scoring='accuracy')

print(f"Cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation score: 0.8126466916354558

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_prob = grid_search.best_estimator_.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Berdasarkan hasil evaluasi, model dapat dikatakan lumayan baik dalam memprediksi apakah penumpang kapal titanic selamat atau tidak, hal ini bisa dilihat dari kurva ROC di mana kurva condong ke kiri atas.
#
# Score AUC yang dihasilkan yaitu 0.85 dan f1-Score-nya yaitu 76.6%, artinya model dapat memprediksi dengan cukup tepat.
#
# (Karena data tidak balance, maka acuan saya adalah f1-Score)

# %% [markdown]
# ## Hyperparameter Tuning using Grid Search - Random Forest

# %%
# only use train data, split it 70:30

from sklearn.model_selection import train_test_split

X = train_df.drop(columns=["Survived"])
y = train_df["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Use grid search to find the best param

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

model = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [5, 10, 15, 20],
    'max_depth': [None, 3, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2'],
}

grid_search = GridSearchCV(model, param_grid, cv=10, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best accuracy:", grid_search.best_score_)
# Out:
# Best parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 20}
# Best accuracy: 0.842652329749104

# %%
y_pred = grid_search.best_estimator_.predict(X_test)

# %%
print(f"Test accuracy: {grid_search.best_estimator_.score(X_test, y_test)}")
print(f"Train accuracy: {grid_search.best_estimator_.score(X_train, y_train)}")
# Out:
# Test accuracy: 0.8171641791044776
# Train accuracy: 0.8892455858747994

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86       157
#            1       0.86      0.67      0.75       111
#
#     accuracy                           0.82       268
#    macro avg       0.83      0.80      0.80       268
# weighted avg       0.82      0.82      0.81       268

# %%
from sklearn.metrics import confusion_matrix

df = pd.DataFrame(confusion_matrix(y_test, y_pred),
                  columns = ["Predicted Positive", "Predicted Negative"],
                  index = ["Actual Positive", "Actual Negative"])

df
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive                 145                  12
# Actual Negative                  37                  74

# %% [markdown]
# Sebanyak 145 orang diprediksi survive, dan aslinya memang survive.
#
# Sebanyak 74 orang diprediksi tidak survive, dan aslinya memang tidak survive.
#
# Sebanyak 12 orang diprediksi tidak survive, tetapi aslinya  survive.
#
# Sebanyak 37 orang diprediksi survive, tetapi aslinya tidak survive.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Precision: {precision_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred)}")
print(f"F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.8171641791044776
# Precision: 0.8604651162790697
# Recall: 0.6666666666666666
# F1 Score: 0.751269035532995

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(grid_search.best_estimator_, X, y, cv=10, scoring='accuracy')

print(f"Cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation score: 0.8249687890137327

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_prob = grid_search.best_estimator_.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Berdasarkan hasil evaluasi, model dapat dikatakan lumayan baik dalam memprediksi apakah penumpang kapal titanic selamat atau tidak, hal ini bisa dilihat dari kurva ROC di mana kurva condong ke kiri atas.
#
# Score AUC yang dihasilkan yaitu 0.86 dan f1-Score-nya yaitu 75.1%, artinya model dapat memprediksi dengan cukup tepat.
#
# (Karena data tidak balance, maka acuan saya adalah f1-Score)

# %% [markdown]
# ## Hyperparameter Tuning using Grid Search - AdaBoost

# %%
# only use train data, split it 70:30

from sklearn.model_selection import train_test_split

X = train_df.drop(columns=["Survived"])
y = train_df["Survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Use grid search to find the best param

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV

model = AdaBoostClassifier(random_state=42)

param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.5, 1.0],
}

grid_search = GridSearchCV(model, param_grid, cv=10, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best accuracy:", grid_search.best_score_)
# Out:
# Best parameters: {'learning_rate': 1.0, 'n_estimators': 200}
# Best accuracy: 0.8137736815156169

# %%
y_pred = grid_search.best_estimator_.predict(X_test)

# %%
print(f"Test accuracy: {grid_search.best_estimator_.score(X_test, y_test)}")
print(f"Train accuracy: {grid_search.best_estimator_.score(X_train, y_train)}")
# Out:
# Test accuracy: 0.8134328358208955
# Train accuracy: 0.8362760834670947

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       157
#            1       0.82      0.70      0.76       111
#
#     accuracy                           0.81       268
#    macro avg       0.82      0.80      0.80       268
# weighted avg       0.81      0.81      0.81       268

# %%
from sklearn.metrics import confusion_matrix

df = pd.DataFrame(confusion_matrix(y_test, y_pred),
                  columns = ["Predicted Positive", "Predicted Negative"],
                  index = ["Actual Positive", "Actual Negative"])

df
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive                 140                  17
# Actual Negative                  33                  78

# %% [markdown]
# Sebanyak 140 orang diprediksi survive, dan aslinya memang survive.
#
# Sebanyak 78 orang diprediksi tidak survive, dan aslinya memang tidak survive.
#
# Sebanyak 17 orang diprediksi tidak survive, tetapi aslinya  survive.
#
# Sebanyak 33 orang diprediksi survive, tetapi aslinya tidak survive.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Precision: {precision_score(y_test, y_pred)}")
print(f"Recall: {recall_score(y_test, y_pred)}")
print(f"F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.8134328358208955
# Precision: 0.8210526315789474
# Recall: 0.7027027027027027
# F1 Score: 0.7572815533980582

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(grid_search.best_estimator_, X, y, cv=10, scoring='accuracy')

print(f"Cross-validation score: {cv_scores.mean()}")
# Out:
# Cross-validation score: 0.8058426966292135

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

y_prob = grid_search.best_estimator_.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Berdasarkan hasil evaluasi, model dapat dikatakan lumayan baik dalam memprediksi apakah penumpang kapal titanic selamat atau tidak, hal ini bisa dilihat dari kurva ROC di mana kurva condong ke kiri atas.
#
# Score AUC yang dihasilkan yaitu 0.86 dan f1-Score-nya yaitu 75.7%, artinya model dapat memprediksi dengan cukup tepat.
#
# (Karena data tidak balance, maka acuan saya adalah f1-Score)
